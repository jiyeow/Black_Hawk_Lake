# %% [markdown]
# This program is used to calculate average flow rate for each ISCO sampling event.
#
# For future development - this code should be modified so that it is able to run in "Terminal" to iterate through all ISCO Flowlink output (raw flow data).

# %%
import pandas as pd

# %%
# I used 99 to mark as the start of sampling event (especialyl useful for to identify when ISCO sampler was restarted)
data = pd.read_csv('T8_all_flow.csv')
data = data.fillna(0)

# %%
data.head()
# Out:
#          Datetime  Flow Rate  Sample Event
# 0  4/6/2015 14:17      0.000           0.0
# 1  4/6/2015 14:18      0.016           0.0
# 2  4/6/2015 14:19      0.024           0.0
# 3  4/6/2015 14:20      0.031           0.0
# 4  4/6/2015 14:21      0.032           0.0

# %%
output = pd.DataFrame(columns=['date_time', 'avg_flow', 'sampling'], index=data.index) 
# this dataframe is too big, but if I remove index=something, the code below won't work.
# just use remove empty rows later on
output.head()
# Out:
#   date_time avg_flow sampling
# 0       NaN      NaN      NaN
# 1       NaN      NaN      NaN
# 2       NaN      NaN      NaN
# 3       NaN      NaN      NaN
# 4       NaN      NaN      NaN

# %%
# fill in missing flow data using linear interpolation
numrows = len(data.index)
i = 1

while i < numrows:
    flow1 = data.iloc[i,1]
    
    if flow1 is None:
        flow1= (data.iloc[i-1,1]+data.iloc[i+1,1])/2

# %%
# calculate average flow each sample
numrows = len(data.index)
#numrows = 5000    #to save time, use 5000 rows for testing

i = 0
y=0
cum_flow = 0
n=0

while i < numrows:
    date1 = data.iloc[i,0]
    flow = data.iloc[i,1]
    sampling = data.iloc[i,2]
    
    if sampling == 0:
        cum_flow = cum_flow + flow
        n=n+1
    else:
        print(date1)
        if n == 0:
            n=1
        avg_flow = cum_flow / n
        # output the values, then reset to zero
        #print(cum_flow)
        #print(avg_flow)
        #print(n)
        output.loc[y].date_time = date1
        output.loc[y].avg_flow = avg_flow
        output.loc[y].sampling = sampling
        y=y+1
        
        n = 0
        cum_flow = 0
    
    i=i+1

# %%
output = output.dropna()
output
# Out:
#            date_time   avg_flow sampling
# 0     4/6/2015 16:50  0.0307059        1
# 1     4/6/2015 19:23  0.0308684        2
# 2     4/6/2015 22:00  0.0300962        3
# 3      4/7/2015 0:39  0.0297215        4
# 4      4/7/2015 3:16  0.0300128        5
# 5      4/7/2015 5:51  0.0304545        6
# 6      4/7/2015 8:28  0.0300962        7
# 7     4/7/2015 11:06  0.0297006        8
# 8     4/7/2015 13:45  0.0298797        9
# 9     4/7/2015 16:19  0.0305163       10
# 10    4/7/2015 18:50  0.0312133       11
# 11    4/7/2015 21:26   0.030271       12
# 12     4/8/2015 0:04  0.0298153       13
# 13     4/8/2015 2:39  0.0305714       14
# 14     4/8/2015 5:07  0.0317823       15
# 15     4/8/2015 7:36  0.0317973       16
# 16    4/8/2015 10:05  0.0315338       17
# 17    4/8/2015 12:33  0.0318639       18
# 18    4/8/2015 15:00  0.0320616       19
# 19    4/8/2015 17:23  0.0329648       20
# 20    4/8/2015 19:45   0.033227       21
# 21    4/8/2015 22:11  0.0324345       22
# 22     4/9/2015 0:36  0.0325139       23
# 23     4/9/2015 3:00  0.0326503       24
# 24   4/17/2015 17:42  0.0881463        1
# 25   4/17/2015 19:24  0.0613069        1
# 26   4/17/2015 21:09  0.0601923        1
# 27   4/17/2015 22:56  0.0592358        1
# 28    4/18/2015 0:43  0.0586226        1
# 29    4/18/2015 2:29  0.0596286        1
# ..               ...        ...      ...
# 639    6/8/2015 0:29   0.124897        3
# 640    6/8/2015 2:37   0.122953        3
# 641    6/8/2015 4:48   0.120508        3
# 642    6/8/2015 7:03   0.116567        3
# 643    6/8/2015 9:22   0.113601        3
# 644   6/8/2015 11:42   0.112396        3
# 645   6/8/2015 14:06   0.109462        3
# 646   6/8/2015 16:31   0.108958        3
# 647   6/8/2015 18:58   0.107151        3
# 648   6/8/2015 21:28    0.10549        3
# 649    6/9/2015 0:00   0.103742        3
# 650    6/9/2015 2:33   0.102862        3
# 651    6/9/2015 5:08   0.102104        3
# 652    6/9/2015 7:44   0.100761        4
# 653   6/9/2015 10:22  0.0996051        4
# 654   6/9/2015 15:46  0.0992105        1
# 655   6/9/2015 18:26  0.0985849        1
# 656   6/9/2015 21:05  0.0989494        1
# 657   6/9/2015 23:48  0.0969198        1
# 658   6/10/2015 2:30  0.0971988        1
# 659   6/10/2015 5:15  0.0959207        1
# 660   6/10/2015 8:04   0.093375        1
# 661  6/10/2015 13:08  0.0924224        1
# 662  6/10/2015 16:01  0.0913605        1
# 663  6/10/2015 18:55  0.0906069        1
# 664  6/10/2015 21:50  0.0900402        1
# 665   6/11/2015 0:47   0.089142        1
# 666   6/11/2015 3:48  0.0870111        1
# 667   6/11/2015 6:36  0.0939042        1
# 668   6/11/2015 8:45   0.123594        1
#
# [669 rows x 3 columns]
